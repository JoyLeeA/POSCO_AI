# %% [markdown]
# ## 20200520 Wensday

# %%
import cv2, os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random
from sklearn.utils import shuffle
import pandas as pd

# %% [markdown]
# **First, download data from:**
#
# https://drive.google.com/file/d/0B0d9ZiqAgFkiOHR1NTJhWVJMNEU/view
#
# and save the downloaded data1 folder in the current directory.

# %%
dir_data = "dataset1/"
dir_seg = dir_data + "/annotations_prepped_train/"
dir_img = dir_data + "/images_prepped_train/"

# %% [markdown]
# **Visualize a single segmentation image**
#
# In this data, there are 12 segmentation classes and the image is from a driving car.

# %%
## seaborn has white grid by default so I will get rid of this.
sns.set_style("whitegrid", {'axes.grid' : False})


ldseg = np.array(os.listdir(dir_seg))
## pick the first image file
fnm = ldseg[0]
print(fnm)

## read in the original image and segmentation labels
seg = cv2.imread(dir_seg + fnm ) # (360, 480, 3)
img_is = cv2.imread(dir_img + fnm )
print("seg.shape={}, img_is.shape={}".format(seg.shape,img_is.shape))

## Check the number of labels
mi, ma = np.min(seg), np.max(seg)
n_classes = ma - mi + 1
print("minimum seg = {}, maximum seg = {}, Total number of segmentation classes = {}".format(mi,ma, n_classes))

fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(1,1,1)
ax.imshow(img_is)
ax.set_title("original image")
plt.show()

fig = plt.figure(figsize=(15,10))
for k in range(mi,ma+1):
    ax = fig.add_subplot(3,n_classes/3,k+1)
    ax.imshow((seg == k)*1.0)
    ax.set_title("label = {}".format(k))


plt.show()
# Out:
# 0016E5_01530.png
# seg.shape=(360, 480, 3), img_is.shape=(360, 480, 3)
# minimum seg = 0, maximum seg = 11, Total number of segmentation classes = 12

# %% [markdown]
# **Data preprocessing: Resize image**
#
# To simplify the problem, I will reshape all the images to the same size: (224,224).
# Why (224,224)?
# This is the iamge shape used in VGG and FCN model in this blog uses a network that takes advantage of VGG structure.
# The FCN model becomes easier to explain when the image shape is (224,224).
# However, FCN does not requires the image shape to be (224,224).
#
# Let's visualize how the resizing make the images look like. The images look fine.

# %%
def give_color_to_seg_img(seg,n_classes): #12개 서로 다른 클래스에 서로 다른 색을 넣어주는 함수
    '''
    seg : (input_width,input_height,3)
    '''
    
    if len(seg.shape)==3:
        seg = seg[:,:,0]
    seg_img = np.zeros( (seg.shape[0],seg.shape[1],3) ).astype('float')
    colors = sns.color_palette("hls", n_classes)
    
    for c in range(n_classes):
        segc = (seg == c)
        seg_img[:,:,0] += (segc*( colors[c][0] ))
        seg_img[:,:,1] += (segc*( colors[c][1] ))
        seg_img[:,:,2] += (segc*( colors[c][2] ))

    return(seg_img)

# %%
input_height , input_width = 224 , 224
output_height , output_width = 224 , 224


ldseg = np.array(os.listdir(dir_seg))
for fnm in ldseg[np.random.choice(len(ldseg),3,replace=False)]:
    fnm = fnm.split(".")[0]
    seg = cv2.imread(dir_seg + fnm + ".png") # (360, 480, 3)
    img_is = cv2.imread(dir_img + fnm + ".png")
    seg_img = give_color_to_seg_img(seg,n_classes)

    fig = plt.figure(figsize=(20,40))
    ax = fig.add_subplot(1,4,1)
    ax.imshow(seg_img)
    
    ax = fig.add_subplot(1,4,2)
    ax.imshow(img_is/255.0)
    ax.set_title("original image {}".format(img_is.shape[:2]))
    
    ax = fig.add_subplot(1,4,3)
    ax.imshow(cv2.resize(seg_img,(input_height , input_width)))
    
    ax = fig.add_subplot(1,4,4)
    ax.imshow(cv2.resize(img_is,(output_height , output_width))/255.0)
    ax.set_title("resized to {}".format((output_height , output_width)))
    plt.show()

# %%
def getImageArr( path , width , height ):
        img = cv2.imread(path, 1)
        img = np.float32(cv2.resize(img, ( width , height ))) / 127.5 - 1
        return img

def getSegmentationArr( path , nClasses ,  width , height  ):
#라벨을 만들어주는 코드 (0으로 되어있는 부분만 1, 나머지는 0/ 다음에는 1으로 되어있는 부분만 1, 나머지는 0 ...)
    seg_labels = np.zeros((  height , width  , nClasses ))
    img = cv2.imread(path, 1)
    img = cv2.resize(img, ( width , height ))
    img = img[:, : , 0]

    for c in range(nClasses):
        seg_labels[: , : , c ] = (img == c ).astype(int)
    ##seg_labels = np.reshape(seg_labels, ( width*height,nClasses  ))
    return seg_labels

# %% [markdown]
# Resize all the images. We have 367 images in this dataset

# %%
images = os.listdir(dir_img)
images.sort()
segmentations  = os.listdir(dir_seg)
segmentations.sort()
    
X = []
Y = []
for im , seg in zip(images,segmentations) :
    X.append( getImageArr(dir_img + im , input_width , input_height )  )
    Y.append( getSegmentationArr( dir_seg + seg , n_classes , output_width , output_height )  )

X, Y = np.array(X) , np.array(Y)
print(X.shape,Y.shape)
# Out:
# (367, 224, 224, 3) (367, 224, 224, 12)

# %% [markdown]
# Import Keras and Tensorflow to develop deep learning FCN models

# %%
## Import usual libraries
import tensorflow as tf
from keras.backend.tensorflow_backend import set_session
import keras, sys, time, warnings
from keras.models import *
from keras.layers import *
from keras import optimizers
# Out:
# Using TensorFlow backend.

# %%
print("python {}".format(sys.version))
print("keras version {}".format(keras.__version__)); del keras
print("tensorflow version {}".format(tf.__version__))
# Out:
# python 3.7.3 (default, Mar 27 2019, 22:11:17)
# [GCC 7.3.0]
# keras version 2.2.4
# tensorflow version 1.13.1

# %%
## location of VGG weights
VGG_Weights_path = "vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5"

# %% [markdown]
# **Homework** ->
# Make FCN8 based on FCN16

# %%
# 네트워크를 구성하는 함수
def FCN16(nClasses ,  input_height=224, input_width=224):
    ## input_height and width must be devisible by 32 because maxpooling with filter size = (2,2) is operated 5 times,
    ## which makes the input_height and width 2^5 = 32 times smaller
    assert input_height%32 == 0 #32로 나눠서 떨어지지 않으면 오류 생성
    assert input_width%32 == 0
    IMAGE_ORDERING =  "channels_last" 

    img_input = Input(shape=(input_height,input_width, 3)) ## Assume 224,224,3
    
    ## Block 1
    x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv1', data_format=IMAGE_ORDERING )(img_input)
    x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv2', data_format=IMAGE_ORDERING )(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block1_pool', data_format=IMAGE_ORDERING )(x)
    f1 = x # 중간 feature map 저장
    
    # Block 2
    x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv1', data_format=IMAGE_ORDERING )(x)
    x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv2', data_format=IMAGE_ORDERING )(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block2_pool', data_format=IMAGE_ORDERING )(x)
    f2 = x

    # Block 3
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv1', data_format=IMAGE_ORDERING )(x)
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv2', data_format=IMAGE_ORDERING )(x)
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv3', data_format=IMAGE_ORDERING )(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block3_pool', data_format=IMAGE_ORDERING )(x)
    pool3 = x

    # Block 4
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv1', data_format=IMAGE_ORDERING )(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv2', data_format=IMAGE_ORDERING )(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv3', data_format=IMAGE_ORDERING )(x)
    pool4 = MaxPooling2D((2, 2), strides=(2, 2), name='block4_pool', data_format=IMAGE_ORDERING )(x)## (None, 14, 14, 512) 

    # Block 5
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv1', data_format=IMAGE_ORDERING )(pool4)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv2', data_format=IMAGE_ORDERING )(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv3', data_format=IMAGE_ORDERING )(x)
    pool5 = MaxPooling2D((2, 2), strides=(2, 2), name='block5_pool', data_format=IMAGE_ORDERING )(x)## (None, 7, 7, 512)

    #x = Flatten(name='flatten')(x)
    #x = Dense(4096, activation='relu', name='fc1')(x)
    # <--> o = ( Conv2D( 4096 , ( 7 , 7 ) , activation='relu' , padding='same', data_format=IMAGE_ORDERING))(o)
    # assuming that the input_height = input_width = 224 as in VGG data
    
    #x = Dense(4096, activation='relu', name='fc2')(x)
    # <--> o = ( Conv2D( 4096 , ( 1 , 1 ) , activation='relu' , padding='same', data_format=IMAGE_ORDERING))(o)   
    # assuming that the input_height = input_width = 224 as in VGG data
    
    #x = Dense(1000 , activation='softmax', name='predictions')(x)
    # <--> o = ( Conv2D( nClasses ,  ( 1 , 1 ) ,kernel_initializer='he_normal' , data_format=IMAGE_ORDERING))(o)
    # assuming that the input_height = input_width = 224 as in VGG data
    
    
    vgg  = Model(  img_input , pool5  )
    vgg.load_weights(VGG_Weights_path) ## loading VGG weights for the encoder parts of FCN8
    
    n = 4096 # fliter
    o = ( Conv2D( n , ( 7 , 7 ) , activation='relu' , padding='same', name="conv6", data_format=IMAGE_ORDERING))(pool5)
    conv7 = ( Conv2D( n , ( 1 , 1 ) , activation='relu' , padding='same', name="conv7", data_format=IMAGE_ORDERING))(o)
    
    
    ## 4 times upsamping for pool4 layer
    conv7_2 = Conv2DTranspose( nClasses , kernel_size=(2,2) ,  strides=(2,2) , use_bias=False, data_format=IMAGE_ORDERING )(conv7)
    ## (None, 224, 224, 10)
    ## 2 times upsampling for pool411
    pool411 = ( Conv2D( nClasses , ( 1 , 1 ) , activation='relu' , padding='same', name="pool4_11", data_format=IMAGE_ORDERING))(pool4)
   ## 1x1 convolution 
    
   #### FCN 16 #### 
    o = Add(name="add")([pool411, conv7_2])
    o = Conv2DTranspose( nClasses , kernel_size=(16,16) ,  strides=(16,16) , use_bias=False, data_format=IMAGE_ORDERING )(o)
    o = (Activation('softmax'))(o)
    
    #### FCN8 ####
#     o = Add(name="add")([pool411, conv7_2])
#     o = Conv2DTranspose( nClasses , kernel_size=(2,2) ,  strides=(2,2) , use_bias=False, data_format=IMAGE_ORDERING )(o)
#     pool311 = ( Conv2D( nClasses , ( 1 , 1 ) , activation='relu' , padding='same', name="pool4_11", data_format=IMAGE_ORDERING))(pool3)
#     o = Add(name="add")([pool311, o])
#     o = Conv2DTranspose( nClasses , kernel_size=(8,8) ,  strides=(8,8) , use_bias=False, data_format=IMAGE_ORDERING )(o)
#     o = (Activation('softmax'))(o)
    
    model = Model(img_input, o)

    return model

# %%
model = FCN16(nClasses     = n_classes,  
             input_height = 224, 
             input_width  = 224)
model.summary()
# Out:
# WARNING:tensorflow:From /home/pirl/anaconda3/envs/edu/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 224, 224, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 224, 224, 64) 36928       block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, 112, 112, 64) 0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv2D)           (None, 112, 112, 128 73856       block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv2D)           (None, 112, 112, 128 147584      block2_conv1[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 56, 56, 128)  0           block2_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv2D)           (None, 56, 56, 256)  295168      block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv2D)           (None, 56, 56, 256)  590080      block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv3 (Conv2D)           (None, 56, 56, 256)  590080      block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 28, 28, 256)  0           block3_conv3[0][0]
# __________________________________________________________________________________________________
# block4_conv1 (Conv2D)           (None, 28, 28, 512)  1180160     block3_pool[0][0]
# __________________________________________________________________________________________________
# block4_conv2 (Conv2D)           (None, 28, 28, 512)  2359808     block4_conv1[0][0]
# __________________________________________________________________________________________________
# block4_conv3 (Conv2D)           (None, 28, 28, 512)  2359808     block4_conv2[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 14, 14, 512)  0           block4_conv3[0][0]
# __________________________________________________________________________________________________
# block5_conv1 (Conv2D)           (None, 14, 14, 512)  2359808     block4_pool[0][0]
# __________________________________________________________________________________________________
# block5_conv2 (Conv2D)           (None, 14, 14, 512)  2359808     block5_conv1[0][0]
# __________________________________________________________________________________________________
# block5_conv3 (Conv2D)           (None, 14, 14, 512)  2359808     block5_conv2[0][0]
# __________________________________________________________________________________________________
# block5_pool (MaxPooling2D)      (None, 7, 7, 512)    0           block5_conv3[0][0]
# __________________________________________________________________________________________________
# conv6 (Conv2D)                  (None, 7, 7, 4096)   102764544   block5_pool[0][0]
# __________________________________________________________________________________________________
# conv7 (Conv2D)                  (None, 7, 7, 4096)   16781312    conv6[0][0]
# __________________________________________________________________________________________________
# pool4_11 (Conv2D)               (None, 14, 14, 12)   6156        block4_pool[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 14, 14, 12)   196608      conv7[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 14, 14, 12)   0           pool4_11[0][0]
#                                                                  conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 224, 224, 12) 36864       add[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 224, 224, 12) 0           conv2d_transpose_2[0][0]
# ==================================================================================================
# Total params: 134,500,172
# Trainable params: 134,500,172
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# Split between training and testing data

# %%
train_rate = 0.85
index_train = np.random.choice(X.shape[0],int(X.shape[0]*train_rate),replace=False)
index_test  = list(set(range(X.shape[0])) - set(index_train))
                            
X, Y = shuffle(X,Y)
X_train, y_train = X[index_train],Y[index_train]
X_test, y_test = X[index_test],Y[index_test]
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (311, 224, 224, 3) (311, 224, 224, 12)
# (56, 224, 224, 3) (56, 224, 224, 12)

# %% [markdown]
# **Training starts here**

# %%
sgd = optimizers.SGD(lr=1E-2, decay=5**(-4), momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy',
              optimizer=sgd,
              metrics=['accuracy'])

hist1 = model.fit(X_train,y_train,
                  validation_data=(X_test,y_test),
                  batch_size=32,epochs=250)
# Out:
# WARNING:tensorflow:From /home/pirl/anaconda3/envs/edu/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /home/pirl/anaconda3/envs/edu/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# Train on 311 samples, validate on 56 samples
# Epoch 1/250
#  - 17s - loss: 2.4896 - acc: 0.0835 - val_loss: 2.4853 - val_acc: 0.0879
# Epoch 2/250
#  - 5s - loss: 2.4832 - acc: 0.0934 - val_loss: 2.4812 - val_acc: 0.0998
# Epoch 3/250
#  - 5s - loss: 2.4768 - acc: 0.1093 - val_loss: 2.4708 - val_acc: 0.1193
# Epoch 4/250
#  - 5s - loss: 2.4534 - acc: 0.1379 - val_loss: 2.4259 - val_acc: 0.1588
# Epoch 5/250
#  - 5s - loss: 2.3511 - acc: 0.1996 - val_loss: 2.2410 - val_acc: 0.2421
# Epoch 6/250
#  - 5s - loss: 2.0492 - acc: 0.3113 - val_loss: 2.0850 - val_acc: 0.3584
# Epoch 7/250
#  - 5s - loss: 1.8975 - acc: 0.3928 - val_loss: 1.7154 - val_acc: 0.4114
# Epoch 8/250
#  - 5s - loss: 1.5890 - acc: 0.4718 - val_loss: 1.5124 - val_acc: 0.5257
# Epoch 9/250
#  - 5s - loss: 1.3795 - acc: 0.5906 - val_loss: 1.3447 - val_acc: 0.6035
# Epoch 10/250
#  - 5s - loss: 1.1839 - acc: 0.6667 - val_loss: 1.1601 - val_acc: 0.6563
# Epoch 11/250
#  - 5s - loss: 1.0808 - acc: 0.6826 - val_loss: 1.1083 - val_acc: 0.6586
# Epoch 12/250
#  - 5s - loss: 1.0298 - acc: 0.6861 - val_loss: 1.0896 - val_acc: 0.6620
# Epoch 13/250
#  - 5s - loss: 1.0028 - acc: 0.6885 - val_loss: 1.0485 - val_acc: 0.6641
# Epoch 14/250
#  - 5s - loss: 0.9898 - acc: 0.6877 - val_loss: 1.0616 - val_acc: 0.6620
# Epoch 15/250
#  - 5s - loss: 0.9617 - acc: 0.6892 - val_loss: 1.0128 - val_acc: 0.6655
# Epoch 16/250
#  - 5s - loss: 0.9367 - acc: 0.6914 - val_loss: 0.9978 - val_acc: 0.6664
# Epoch 17/250
#  - 5s - loss: 0.9216 - acc: 0.6927 - val_loss: 0.9904 - val_acc: 0.6678
# Epoch 18/250
#  - 5s - loss: 0.9063 - acc: 0.6941 - val_loss: 0.9621 - val_acc: 0.6703
# Epoch 19/250
#  - 5s - loss: 0.9038 - acc: 0.6947 - val_loss: 0.9517 - val_acc: 0.6709
# Epoch 20/250
#  - 5s - loss: 0.8802 - acc: 0.6982 - val_loss: 0.9318 - val_acc: 0.6758
# Epoch 21/250
#  - 5s - loss: 0.8634 - acc: 0.7036 - val_loss: 0.9207 - val_acc: 0.6822
# Epoch 22/250
#  - 5s - loss: 0.8505 - acc: 0.7109 - val_loss: 0.8954 - val_acc: 0.6969
# Epoch 23/250
#  - 5s - loss: 0.8584 - acc: 0.7187 - val_loss: 0.8967 - val_acc: 0.7049
# Epoch 24/250
#  - 5s - loss: 0.8180 - acc: 0.7318 - val_loss: 0.8615 - val_acc: 0.7238
# Epoch 25/250
#  - 5s - loss: 0.7944 - acc: 0.7493 - val_loss: 0.8355 - val_acc: 0.7409
# Epoch 26/250
#  - 5s - loss: 0.7852 - acc: 0.7597 - val_loss: 0.8195 - val_acc: 0.7524
# Epoch 27/250
#  - 5s - loss: 0.7649 - acc: 0.7704 - val_loss: 0.8009 - val_acc: 0.7644
# Epoch 28/250
#  - 5s - loss: 0.7424 - acc: 0.7826 - val_loss: 0.8086 - val_acc: 0.7600
# Epoch 29/250
#  - 5s - loss: 0.7204 - acc: 0.7901 - val_loss: 0.7854 - val_acc: 0.7684
# Epoch 30/250
#  - 5s - loss: 0.7095 - acc: 0.7930 - val_loss: 0.7512 - val_acc: 0.7806
# Epoch 159/250
#  - 5s - loss: 0.4112 - acc: 0.8862 - val_loss: 0.5375 - val_acc: 0.8472
# Epoch 160/250
#  - 5s - loss: 0.4142 - acc: 0.8852 - val_loss: 0.5351 - val_acc: 0.8476
# Epoch 161/250
#  - 5s - loss: 0.4106 - acc: 0.8863 - val_loss: 0.5384 - val_acc: 0.8465
# Epoch 162/250
#  - 5s - loss: 0.4143 - acc: 0.8854 - val_loss: 0.5350 - val_acc: 0.8477
# Epoch 163/250
#  - 5s - loss: 0.4114 - acc: 0.8860 - val_loss: 0.5447 - val_acc: 0.8447
# Epoch 164/250
#  - 5s - loss: 0.4096 - acc: 0.8866 - val_loss: 0.5386 - val_acc: 0.8467
# Epoch 165/250
#  - 5s - loss: 0.4084 - acc: 0.8870 - val_loss: 0.5343 - val_acc: 0.8478
# Epoch 166/250
#  - 5s - loss: 0.4078 - acc: 0.8873 - val_loss: 0.5365 - val_acc: 0.8474
# Epoch 167/250
#  - 5s - loss: 0.4102 - acc: 0.8863 - val_loss: 0.5388 - val_acc: 0.8472
# Epoch 168/250
#  - 5s - loss: 0.4069 - acc: 0.8875 - val_loss: 0.5342 - val_acc: 0.8482
# Epoch 169/250
#  - 5s - loss: 0.4055 - acc: 0.8879 - val_loss: 0.5347 - val_acc: 0.8479
# Epoch 170/250
#  - 5s - loss: 0.4056 - acc: 0.8878 - val_loss: 0.5330 - val_acc: 0.8479
# Epoch 171/250
#  - 5s - loss: 0.4053 - acc: 0.8880 - val_loss: 0.5396 - val_acc: 0.8470
# Epoch 172/250
#  - 5s - loss: 0.4060 - acc: 0.8877 - val_loss: 0.5322 - val_acc: 0.8483
# Epoch 173/250
#  - 5s - loss: 0.4034 - acc: 0.8886 - val_loss: 0.5374 - val_acc: 0.8481
# Epoch 174/250
#  - 5s - loss: 0.4088 - acc: 0.8866 - val_loss: 0.5351 - val_acc: 0.8484
# Epoch 175/250
#  - 5s - loss: 0.4042 - acc: 0.8883 - val_loss: 0.5315 - val_acc: 0.8487
# Epoch 176/250
#  - 5s - loss: 0.4032 - acc: 0.8887 - val_loss: 0.5340 - val_acc: 0.8481
# Epoch 177/250
#  - 5s - loss: 0.4024 - acc: 0.8888 - val_loss: 0.5319 - val_acc: 0.8480
# Epoch 178/250
#  - 5s - loss: 0.4037 - acc: 0.8883 - val_loss: 0.5308 - val_acc: 0.8489
# Epoch 179/250
#  - 5s - loss: 0.4008 - acc: 0.8894 - val_loss: 0.5318 - val_acc: 0.8493
# Epoch 180/250
#  - 5s - loss: 0.4007 - acc: 0.8893 - val_loss: 0.5302 - val_acc: 0.8488
# Epoch 181/250
#  - 5s - loss: 0.4012 - acc: 0.8891 - val_loss: 0.5292 - val_acc: 0.8493
# Epoch 182/250
#  - 5s - loss: 0.4028 - acc: 0.8885 - val_loss: 0.5386 - val_acc: 0.8463
# Epoch 183/250
#  - 5s - loss: 0.4044 - acc: 0.8879 - val_loss: 0.5309 - val_acc: 0.8493
# Epoch 184/250
#  - 5s - loss: 0.3990 - acc: 0.8897 - val_loss: 0.5313 - val_acc: 0.8494
# Epoch 185/250
#  - 5s - loss: 0.4027 - acc: 0.8886 - val_loss: 0.5329 - val_acc: 0.8486
# Epoch 186/250
#  - 5s - loss: 0.4001 - acc: 0.8894 - val_loss: 0.5309 - val_acc: 0.8497
# Epoch 187/250
#  - 5s - loss: 0.3979 - acc: 0.8901 - val_loss: 0.5301 - val_acc: 0.8491
# Epoch 188/250
#  - 5s - loss: 0.4001 - acc: 0.8893 - val_loss: 0.5289 - val_acc: 0.8495
# Epoch 189/250
#  - 5s - loss: 0.3966 - acc: 0.8906 - val_loss: 0.5289 - val_acc: 0.8501
# Epoch 190/250
#  - 5s - loss: 0.3960 - acc: 0.8908 - val_loss: 0.5283 - val_acc: 0.8500
# Epoch 191/250
#  - 5s - loss: 0.3952 - acc: 0.8911 - val_loss: 0.5310 - val_acc: 0.8499
# Epoch 192/250
#  - 5s - loss: 0.3957 - acc: 0.8908 - val_loss: 0.5286 - val_acc: 0.8503
# Epoch 193/250
#  - 5s - loss: 0.3957 - acc: 0.8908 - val_loss: 0.5302 - val_acc: 0.8497
# Epoch 194/250
#  - 5s - loss: 0.3951 - acc: 0.8908 - val_loss: 0.5306 - val_acc: 0.8493
# Epoch 195/250
#  - 5s - loss: 0.3949 - acc: 0.8910 - val_loss: 0.5287 - val_acc: 0.8491
# Epoch 196/250
#  - 5s - loss: 0.3980 - acc: 0.8898 - val_loss: 0.5293 - val_acc: 0.8490
# Epoch 197/250
#  - 5s - loss: 0.3972 - acc: 0.8901 - val_loss: 0.5285 - val_acc: 0.8501
# Epoch 198/250
#  - 5s - loss: 0.3955 - acc: 0.8906 - val_loss: 0.5444 - val_acc: 0.8462
# Epoch 199/250
#  - 5s - loss: 0.3963 - acc: 0.8904 - val_loss: 0.5266 - val_acc: 0.8503
# Epoch 200/250
#  - 5s - loss: 0.3920 - acc: 0.8918 - val_loss: 0.5268 - val_acc: 0.8494
# Epoch 201/250
#  - 5s - loss: 0.3917 - acc: 0.8919 - val_loss: 0.5274 - val_acc: 0.8503
# Epoch 202/250
#  - 5s - loss: 0.3913 - acc: 0.8920 - val_loss: 0.5287 - val_acc: 0.8501
# Epoch 203/250
#  - 5s - loss: 0.3923 - acc: 0.8917 - val_loss: 0.5300 - val_acc: 0.8494
# Epoch 204/250
#  - 5s - loss: 0.3908 - acc: 0.8922 - val_loss: 0.5277 - val_acc: 0.8506
# Epoch 205/250
#  - 5s - loss: 0.3910 - acc: 0.8921 - val_loss: 0.5311 - val_acc: 0.8497
# Epoch 206/250
#  - 5s - loss: 0.3924 - acc: 0.8917 - val_loss: 0.5300 - val_acc: 0.8498
# Epoch 207/250
#  - 5s - loss: 0.3895 - acc: 0.8925 - val_loss: 0.5273 - val_acc: 0.8509
# Epoch 208/250
#  - 5s - loss: 0.3887 - acc: 0.8928 - val_loss: 0.5266 - val_acc: 0.8511
# Epoch 209/250
#  - 5s - loss: 0.3893 - acc: 0.8926 - val_loss: 0.5266 - val_acc: 0.8510
# Epoch 210/250
#  - 5s - loss: 0.3887 - acc: 0.8928 - val_loss: 0.5292 - val_acc: 0.8506
# Epoch 211/250
#  - 5s - loss: 0.3907 - acc: 0.8919 - val_loss: 0.5256 - val_acc: 0.8507
# Epoch 212/250
#  - 5s - loss: 0.3877 - acc: 0.8931 - val_loss: 0.5255 - val_acc: 0.8510
# Epoch 213/250
#  - 5s - loss: 0.3873 - acc: 0.8931 - val_loss: 0.5262 - val_acc: 0.8509
# Epoch 214/250
#  - 5s - loss: 0.3895 - acc: 0.8924 - val_loss: 0.5345 - val_acc: 0.8500
# Epoch 215/250
#  - 5s - loss: 0.3896 - acc: 0.8924 - val_loss: 0.5307 - val_acc: 0.8506
# Epoch 216/250
#  - 5s - loss: 0.3888 - acc: 0.8926 - val_loss: 0.5261 - val_acc: 0.8510
# Epoch 217/250
#  - 5s - loss: 0.3856 - acc: 0.8937 - val_loss: 0.5270 - val_acc: 0.8509
# Epoch 218/250
#  - 5s - loss: 0.3874 - acc: 0.8931 - val_loss: 0.5285 - val_acc: 0.8510
# Epoch 219/250
#  - 5s - loss: 0.3852 - acc: 0.8937 - val_loss: 0.5259 - val_acc: 0.8513
# Epoch 220/250
#  - 5s - loss: 0.3872 - acc: 0.8929 - val_loss: 0.5291 - val_acc: 0.8503
# Epoch 221/250
#  - 5s - loss: 0.3855 - acc: 0.8935 - val_loss: 0.5259 - val_acc: 0.8514
# Epoch 222/250
#  - 5s - loss: 0.3847 - acc: 0.8939 - val_loss: 0.5259 - val_acc: 0.8511
# Epoch 223/250
#  - 5s - loss: 0.3838 - acc: 0.8942 - val_loss: 0.5252 - val_acc: 0.8511
# Epoch 224/250
#  - 5s - loss: 0.3850 - acc: 0.8937 - val_loss: 0.5246 - val_acc: 0.8514
# Epoch 225/250
#  - 5s - loss: 0.3832 - acc: 0.8943 - val_loss: 0.5236 - val_acc: 0.8515
# Epoch 226/250
#  - 5s - loss: 0.3830 - acc: 0.8944 - val_loss: 0.5266 - val_acc: 0.8509
# Epoch 227/250
#  - 5s - loss: 0.3850 - acc: 0.8935 - val_loss: 0.5265 - val_acc: 0.8510
# Epoch 228/250
#  - 5s - loss: 0.3829 - acc: 0.8943 - val_loss: 0.5237 - val_acc: 0.8519
# Epoch 229/250
#  - 5s - loss: 0.3855 - acc: 0.8933 - val_loss: 0.5233 - val_acc: 0.8519
# Epoch 230/250
#  - 5s - loss: 0.3814 - acc: 0.8948 - val_loss: 0.5234 - val_acc: 0.8515
# Epoch 231/250
#  - 5s - loss: 0.3817 - acc: 0.8946 - val_loss: 0.5259 - val_acc: 0.8514
# Epoch 232/250
#  - 5s - loss: 0.3835 - acc: 0.8942 - val_loss: 0.5243 - val_acc: 0.8520
# Epoch 233/250
#  - 5s - loss: 0.3808 - acc: 0.8950 - val_loss: 0.5242 - val_acc: 0.8515
# Epoch 234/250
#  - 5s - loss: 0.3811 - acc: 0.8948 - val_loss: 0.5238 - val_acc: 0.8515
# Epoch 235/250
#  - 5s - loss: 0.3799 - acc: 0.8952 - val_loss: 0.5234 - val_acc: 0.8516
# Epoch 236/250
#  - 5s - loss: 0.3827 - acc: 0.8943 - val_loss: 0.5240 - val_acc: 0.8512
# Epoch 237/250
#  - 5s - loss: 0.3836 - acc: 0.8937 - val_loss: 0.5227 - val_acc: 0.8523
# Epoch 238/250
#  - 5s - loss: 0.3793 - acc: 0.8953 - val_loss: 0.5229 - val_acc: 0.8520
# Epoch 239/250
#  - 5s - loss: 0.3786 - acc: 0.8956 - val_loss: 0.5242 - val_acc: 0.8520
# Epoch 240/250
#  - 5s - loss: 0.3787 - acc: 0.8956 - val_loss: 0.5237 - val_acc: 0.8519
# Epoch 241/250
#  - 5s - loss: 0.3785 - acc: 0.8956 - val_loss: 0.5256 - val_acc: 0.8514
# Epoch 242/250
#  - 5s - loss: 0.3794 - acc: 0.8952 - val_loss: 0.5233 - val_acc: 0.8519
# Epoch 243/250
#  - 5s - loss: 0.3795 - acc: 0.8951 - val_loss: 0.5223 - val_acc: 0.8520
# Epoch 244/250
#  - 5s - loss: 0.3785 - acc: 0.8957 - val_loss: 0.5225 - val_acc: 0.8519
# Epoch 245/250
#  - 5s - loss: 0.3776 - acc: 0.8958 - val_loss: 0.5227 - val_acc: 0.8523
# Epoch 246/250
#  - 5s - loss: 0.3779 - acc: 0.8956 - val_loss: 0.5242 - val_acc: 0.8524
# Epoch 247/250
#  - 5s - loss: 0.3770 - acc: 0.8960 - val_loss: 0.5260 - val_acc: 0.8516
# Epoch 248/250
#  - 5s - loss: 0.3782 - acc: 0.8956 - val_loss: 0.5227 - val_acc: 0.8518
# Epoch 249/250
#  - 5s - loss: 0.3770 - acc: 0.8959 - val_loss: 0.5238 - val_acc: 0.8526
# Epoch 250/250
#  - 5s - loss: 0.3766 - acc: 0.8961 - val_loss: 0.5236 - val_acc: 0.8523

# %% [markdown]
# Plot the change in loss over epochs

# %%
for key in ['loss', 'val_loss']:
    plt.plot(hist1.history[key],label=key)
plt.legend()
plt.show()

# %% [markdown]
# Calculate intersection over union for each segmentation class

# %%
y_pred = model.predict(X_test)
y_predi = np.argmax(y_pred, axis=3)
y_testi = np.argmax(y_test, axis=3)
print(y_testi.shape,y_predi.shape)
# Out:
# (56, 224, 224) (56, 224, 224)

# %%
def IoU(Yi,y_predi):
    ## mean Intersection over Union
    ## Mean IoU = TP/(FN + TP + FP)

    IoUs = []
    Nclass = int(np.max(Yi)) + 1
    for c in range(Nclass):
        TP = np.sum( (Yi == c)&(y_predi==c) )
        FP = np.sum( (Yi != c)&(y_predi==c) )
        FN = np.sum( (Yi == c)&(y_predi != c)) 
        IoU = TP/float(TP + FP + FN)
        print("class {:02.0f}: #TP={:6.0f}, #FP={:6.0f}, #FN={:5.0f}, IoU={:4.3f}".format(c,TP,FP,FN,IoU))
        IoUs.append(IoU)
    mIoU = np.mean(IoUs)
    print("_________________")
    print("Mean IoU: {:4.3f}".format(mIoU))

# %%
IoU(y_testi,y_predi)
# Out:
# class 00: #TP=432723, #FP= 47103, #FN=25140, IoU=0.857
# class 01: #TP=541118, #FP=121094, #FN=48964, IoU=0.761
# class 02: #TP=     4, #FP=    82, #FN=32673, IoU=0.000
# class 03: #TP=868284, #FP= 36606, #FN=35972, IoU=0.923
# class 04: #TP= 91206, #FP= 34280, #FN=39507, IoU=0.553
# class 05: #TP=255245, #FP= 78855, #FN=53425, IoU=0.659
# class 06: #TP=  3849, #FP=  4630, #FN=31329, IoU=0.097
# class 07: #TP= 23269, #FP= 14762, #FN=32811, IoU=0.328
# class 08: #TP=133244, #FP= 32762, #FN=32526, IoU=0.671
# class 09: #TP=   554, #FP=  2215, #FN=18186, IoU=0.026
# class 10: #TP=   444, #FP=   493, #FN=13234, IoU=0.031
# class 11: #TP= 44874, #FP= 42160, #FN=51275, IoU=0.324
# _________________
# Mean IoU: 0.436

# %% [markdown]
# **Visualize the model performance**
#
#
# Looks reasonable!

# %%
shape = (224,224)
n_classes= 10

for i in range(10):
    img_is  = (X_test[i] + 1)*(255.0/2)
    seg = y_predi[i]
    segtest = y_testi[i]

    fig = plt.figure(figsize=(10,30))    
    ax = fig.add_subplot(1,3,1)
    ax.imshow(img_is/255.0)
    ax.set_title("original")
    
    ax = fig.add_subplot(1,3,2)
    ax.imshow(give_color_to_seg_img(seg,n_classes))
    ax.set_title("predicted class")
    
    ax = fig.add_subplot(1,3,3)
    ax.imshow(give_color_to_seg_img(segtest,n_classes))
    ax.set_title("true class")
    plt.show()
